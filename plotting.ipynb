# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

def plot_file(filename, pt=False):
    vals = np.loadtxt(filename)
    
    if pt: print(vals)
    for i in range(1, len(vals)):
        plt.plot(vals[0], vals[i])
    return vals

# %%
plot_file("values.txt")
# print(vals)
plt.savefig("small.png")

# %%
plot_file("curve_vals.txt")

# %%
v = plot_file("diffuse_vals.txt")

# %%
v = plot_file("inner_radius_71.txt")
plt.grid(True, which='both')
# plt.savefig("inner_radius.png")
l = len(v[0]) // 2
xs = v[0][:l]
ys = v[1][:l]
zs = v[2][:l]
us = v[3][:l]
assert(len(xs) == len(ys))
print(np.polyfit(xs, ys, 1))
print(np.polyfit(xs, zs, 2))
print(np.polyfit(xs, us, 1))

xs = v[0][l:]
ys = v[1][l:]
zs = v[2][l:]
# us = v[3][l:]
print(np.polyfit(xs, ys, 1))
# print(np.polyfit(xs, zs, 2))
# print(np.polyfit(xs, us, 1))
# print(v[1][50:52])

v2 = plot_file("inner_radius_41.txt")
l = len(v2[0]) // 2
xs = v2[0][:l]
ys = v2[1][:l]
zs = v2[2][:l]
us = v2[3][:l]
assert(len(xs) == len(ys))
# print(np.polyfit(xs, ys, 2))
# print(np.polyfit(xs, zs, 2))
# print(np.polyfit(xs, us, 1))
# Out:
# [ 1.40106194 -0.0327549 ]
# [ -8.56632895e-01   1.01868841e+00  -8.25411855e-04]
# [-2.  1.]
# [ 0.57898952  0.40648404]

# %%
v = plot_file("inner_radius2.txt")
# plt.savefig("inner_radius.png")
plt.grid(True)

# %%
v = plot_file("inner_radius_angle.txt")
