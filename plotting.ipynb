# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
vals = np.loadtxt("values.txt")
print(vals)
plt.plot(vals[0], vals[1], vals[0], vals[2])
# Out:
# [[ 0.25      0.275     0.3       0.325     0.35      0.375     0.4       0.425
#    0.45      0.475     0.5     ]
#  [ 1.        0.843566  0.690983  0.546009  0.412215  0.292893  0.190983
#    0.108994  0.048944  0.012312  0.      ]
#  [ 1.        0.9       0.8       0.7       0.6       0.5       0.4       0.3
#    0.2       0.1       0.      ]]
# ...
