# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
vals = np.loadtxt("values.txt")
# print(vals)
plt.plot(vals[0], vals[1], vals[0], vals[2])
# plt.plot(vals[0], vals[1])
